# %% [markdown]
# EDA(Exploratory data analysis) of Titanic dataset

# %%
#EDA-EXPLORATORTY DATA ANALYSIS
#Extract insights using visual and statistical exploration

# %%
# Importing some important libraries like pandas,matplotlib,seaborn
import pandas as pd# importing pandas libraries
import matplotlib.pyplot as plt# importing matplotlib libraries
import seaborn as sns# importing seaborn libraries

# %%
# Importing the data into notebook
df=pd.read_csv('Titanic-Dataset (1).csv')# load the dataset

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Taking the information of dataset 
df.info()# Retrive the information about data columns and their types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# It gives the summary status of numerical values like min,25%,50%,75%,max.
df.describe()# Retreive the 5 numerical values
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#It gives the summary status of numerical as well as categorical values
df.describe(include='all')# Retreive the 5 points values of numerical as well as categorical data
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
#it count the values
df.value_counts()# counts the value
# Out:
# PassengerId  Survived  Pclass  Name                                                  Sex     Age   SibSp  Parch  Ticket    Fare      Cabin  Embarked
# 2            1         1       Cumings, Mrs. John Bradley (Florence Briggs Thayer)   female  38.0  1      0      PC 17599  71.2833   C85    C           1
# 572          1         1       Appleton, Mrs. Edward Dale (Charlotte Lamson)         female  53.0  2      0      11769     51.4792   C101   S           1
# 578          1         1       Silvey, Mrs. William Baird (Alice Munger)             female  39.0  1      0      13507     55.9000   E44    S           1
# 582          1         1       Thayer, Mrs. John Borland (Marian Longstreth Morris)  female  39.0  1      1      17421     110.8833  C68    C           1
# 584          0         1       Ross, Mr. John Hugo                                   male    36.0  0      0      13049     40.1250   A10    C           1
# ...

# %%
df.duplicated().sum()# Checking the dupliate values.
# Out:
# 0

# %%
df.isnull().sum()# Checking the null values.
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Visualization

# %%
df.isnull().sum()# Checking the column-wise null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop('Cabin', axis=1, inplace=True)# Droping the cabin column which consist too many null values.

# %%
df['Age']=df['Age'].fillna(df['Age'].mean()).# Replace the null values of Age column with mean.

# %%
df['Age']
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'].isna().sum()# Checking the null values in Age column.
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# Visualization

# %%
# PAIRPLOT
sns.pairplot(df[['Age','Fare','Survived']],hue='Survived')# Making the pairplot
# Passengers with higher fare and lower age tend to have a higher chance of survival.
# Survived = 1 (green or blue points) are mostly clustered around low age and high fare regions.

# %%
# HEATMAP
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True, cmap='coolwarm')# Making the heatmap
plt.title("Correlation Heatmap")
plt.show()
#Fare aur Survived ke beech moderate positive correlation hai,
#matlab mehenga ticket lene wale passengers zyada survive hue.Pclass ka Survived ke saath negative correlation hai,
#yani 3rd class mein survival rate kam tha.

# %% [markdown]
# Plots for data visualization

# %%
# SCATTERPLOT
sns.scatterplot(data=df, x='Age', y='Fare', hue='Survived')# Making the scatterplot
plt.title("Age vs Fare (colored by Survival)")
plt.show()
# The chart shows that younger passengers (ages 0–20) who paid higher fares had better chances of survival (more orange dots).
# Most of the passengers who did not survive (blue dots) are in the low fare and mid-age range.

# %%
df[['Age', 'Fare']].isnull().sum()
# Out:
# Age     0
# Fare    0
# dtype: int64

# %%
# HISTPLOT
sns.histplot(data=df, x='Age', bins=30, kde=True)# Making the histplot
plt.title("Age Distribution")
plt.show()
# Most passengers were between the ages of 20 and 40.
# Very few people belonged to the 60+ age group.

# %%
# BOXPLOT BY AGE AND PASSENGER CLASS
sns.boxplot(data=df, x='Pclass', y='Age')# Making the boxplot.
plt.title("Age by Passenger Class")
plt.show()
# The average age of survived passengers is slightly lower.
# Young passengers, especially children, had a higher chance of survival.

# %%
# GROUP BY SURVIVAL RATE
df.groupby('Pclass')['Survived'].mean().plot(kind='bar')# using the groupby in Pclass and Survived columns.
plt.title('Survival Rate by Passenger Class')
plt.ylabel('Survival Rate')
plt.show()
# 1st class passengers had the highest survival rate.
# 3rd class passengers had the lowest survival rate, highlighting the socio-economic gap.

# %%
# BOXPLOT BY FARE AND PCLASS
sns.boxplot(x='Pclass', y='Fare', data=df)
plt.title("Fare Distribution by Passenger Class")
plt.show()
# 1st class passengers paid the highest fares, with several outliers observed.
# Fares in 3rd class were much lower and had a narrower range.

# %%
# GROUP BY SURVIVAL RATE AND GENDER 
df.groupby('Sex')['Survived'].mean().plot(kind='bar')
plt.title('Survival Rate by Gender')
plt.ylabel('Survival Rate')
plt.show()
# The survival rate of women was significantly higher compared to men.
#The impact of the Titanic's rescue policy of 'women and children first' is clearly visible.
